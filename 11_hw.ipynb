# %%
import sympy

# %%
from sympy import trigsimp, sin, cos
from sympy.abc import x, y
expr = sin(x)**2 - cos(x)**2
trigsimp(expr)
# Out:
# -cos(2*x)

# %%
from sympy import diff
expr_diff = sympy.diff(expr)
expr_diff
# Out:
# 4*sin(x)*cos(x)

# %%
expr = sin(x)**2 - cos(x)**2
expr_solve = sympy.solveset(expr)
expr_solve
# Out:
# Union(ImageSet(Lambda(_n, _n*pi + pi/4), Integers), ImageSet(Lambda(_n, _n*pi + 3*pi/4), Integers))

# %%
import matplotlib.pyplot as plt
sympy.plot(expr)

# %%
peak_dif = sympy.solve(expr_diff)
peak_dif
# Out:
# [0, pi/2, pi, 3*pi/2]

# %%
down_dif = sympy.solve(expr_diff<0)
down_dif
# Out:
# (x < pi) & (pi/2 < x)

# %%
rise_dif = sympy.solve(expr_diff>0)
rise_dif
# Out:
# (0 < x) & (x < pi/2)

# %%
down_expr = sympy.solve(expr<0)
down_expr
# Out:
# ((0 <= x) & (x < pi/4)) | ((x < pi) & (3*pi/4 < x))

# %%
rise_expr = sympy.solve(expr>0)
rise_expr
# Out:
# (pi/4 < x) & (x < 3*pi/4)
